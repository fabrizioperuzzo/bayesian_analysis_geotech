# %% [markdown]
# # Bayesian analysis and modern machine learning algorithms applied for soil and rock probabilistic characterization

# %% [markdown]
# ## Introduction

# %% [markdown]
# Modern programming languages made easier the use of statistical analysis of large amount of data.
# The Bayesian analysis is helpful to update knowledge of something.
# Is particularly indicated when we have to deal with classification.
# This is why it is helpful when appled to geotechnical material.
# The instrument we are going to use is pandas packages under python code for what concern the data manipulation.
# The sklearn package and in particular SNN classification will be used in order to verify the omogeneity of the selected sample with respect to the other material obtained from other sample.
# Successively we are going to use the package pcm3 for the bayesian analysis
# An online database by means of Mysql open source will keep storage of the soil material and will be helpful for future analyis.
# The criteria of storing data will be also the geografical area linked to climate and geological period, local atmosfere (lake, sea, desertic) and load history. This will be helpful to assimilate similar soil.

# %% [markdown]
# ## Python packages to deal with data

# %% [markdown]
# We will make extensive use of Pandas packages to deal with data. This packages offer the peculiarity to communicate with a huge amount of data protocols like html, json, xls, db, csv and is constantly update to accomodate recent development like supporting the hdf format that is a development of the csv format but much faster and disk space optimization.
# The following code show how this package will be use to upload data from the excel file.

# %%
import sys

# %%
# !conda install --yes --prefix {sys.prefix} m2w64-toolchain
# after it add to PATH
# ...Anaconda3\pkgs\m2w64-gcc-5.3.0-6\Library\mingw-w64\bin
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Fabrizio\Anaconda3
#
#   added / updated specs:
#     - m2w64-toolchain
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.8.28  |                0         126 KB
#     certifi-2019.9.11          |           py37_0         151 KB
#     conda-4.8.0                |           py37_1         2.8 MB
#     openssl-1.1.1d             |       he774522_2         4.8 MB
#     ------------------------------------------------------------
#                                            Total:         7.9 MB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates                                  anaconda --> pkgs/main
#   certifi                                          anaconda --> pkgs/main
#   conda                                         conda-forge --> pkgs/main
#   openssl                                          anaconda --> pkgs/main
#
#
#
# Downloading and Extracting Packages
#
# conda-4.8.0          | 2.8 MB    |            |   0%
# conda-4.8.0          | 2.8 MB    |            |   1%
# conda-4.8.0          | 2.8 MB    | 3          |   3%
# conda-4.8.0          | 2.8 MB    | 4          |   4%
# conda-4.8.0          | 2.8 MB    | 7          |   7%
# conda-4.8.0          | 2.8 MB    | 9          |   9%
# conda-4.8.0          | 2.8 MB    | #1         |  12%
# conda-4.8.0          | 2.8 MB    | #3         |  13%
# conda-4.8.0          | 2.8 MB    | #4         |  15%
# conda-4.8.0          | 2.8 MB    | #7         |  18%
# conda-4.8.0          | 2.8 MB    | #9         |  20%
# conda-4.8.0          | 2.8 MB    | ##2        |  22%
# conda-4.8.0          | 2.8 MB    | ##6        |  26%
# conda-4.8.0          | 2.8 MB    | ##9        |  30%
# conda-4.8.0          | 2.8 MB    | ###2       |  33%
# conda-4.8.0          | 2.8 MB    | ###7       |  37%
# conda-4.8.0          | 2.8 MB    | ####       |  41%
# conda-4.8.0          | 2.8 MB    | ####4      |  44%
# conda-4.8.0          | 2.8 MB    | ####8      |  48%
# conda-4.8.0          | 2.8 MB    | #####2     |  52%
# conda-4.8.0          | 2.8 MB    | #####5     |  55%
# conda-4.8.0          | 2.8 MB    | #####9     |  59%
# conda-4.8.0          | 2.8 MB    | ######3    |  63%
# conda-4.8.0          | 2.8 MB    | ######6    |  66%
# conda-4.8.0          | 2.8 MB    | #######    |  70%
# conda-4.8.0          | 2.8 MB    | #######4   |  74%
# conda-4.8.0          | 2.8 MB    | #######7   |  77%
# conda-4.8.0          | 2.8 MB    | ########1  |  81%
# conda-4.8.0          | 2.8 MB    | ########5  |  85%
# conda-4.8.0          | 2.8 MB    | ########9  |  89%
# conda-4.8.0          | 2.8 MB    | #########2 |  92%
# conda-4.8.0          | 2.8 MB    | #########5 |  96%
# conda-4.8.0          | 2.8 MB    | #########9 | 100%
# conda-4.8.0          | 2.8 MB    | ########## | 100%
#
# ca-certificates-2019 | 126 KB    |            |   0%
# ca-certificates-2019 | 126 KB    | #2         |  13%
# ca-certificates-2019 | 126 KB    | ########9  |  89%
# ca-certificates-2019 | 126 KB    | ########## | 100%
#
# certifi-2019.9.11    | 151 KB    |            |   0%
# certifi-2019.9.11    | 151 KB    | #          |  11%
# certifi-2019.9.11    | 151 KB    | ########4  |  85%
# certifi-2019.9.11    | 151 KB    | ########## | 100%
#
# openssl-1.1.1d       | 4.8 MB    |            |   0%
# openssl-1.1.1d       | 4.8 MB    |            |   0%
# openssl-1.1.1d       | 4.8 MB    | 2          |   3%
# openssl-1.1.1d       | 4.8 MB    | 4          |   5%
# openssl-1.1.1d       | 4.8 MB    | 6          |   7%
# openssl-1.1.1d       | 4.8 MB    | 9          |   9%
# openssl-1.1.1d       | 4.8 MB    | #1         |  11%
# openssl-1.1.1d       | 4.8 MB    | #2         |  13%
# openssl-1.1.1d       | 4.8 MB    | #5         |  15%
# openssl-1.1.1d       | 4.8 MB    | #7         |  18%
# openssl-1.1.1d       | 4.8 MB    | #9         |  19%
# openssl-1.1.1d       | 4.8 MB    | ##1        |  21%
# openssl-1.1.1d       | 4.8 MB    | ##3        |  24%
# openssl-1.1.1d       | 4.8 MB    | ##5        |  26%
# openssl-1.1.1d       | 4.8 MB    | ##8        |  28%
# openssl-1.1.1d       | 4.8 MB    | ###        |  31%
# openssl-1.1.1d       | 4.8 MB    | ###2       |  32%
# openssl-1.1.1d       | 4.8 MB    | ###4       |  34%
# openssl-1.1.1d       | 4.8 MB    | ###6       |  36%
# openssl-1.1.1d       | 4.8 MB    | ###8       |  38%
# openssl-1.1.1d       | 4.8 MB    | ####       |  40%
# openssl-1.1.1d       | 4.8 MB    | ####2      |  42%
# openssl-1.1.1d       | 4.8 MB    | ####4      |  44%
# openssl-1.1.1d       | 4.8 MB    | ####6      |  46%
# openssl-1.1.1d       | 4.8 MB    | ####8      |  49%
# openssl-1.1.1d       | 4.8 MB    | #####      |  51%
# openssl-1.1.1d       | 4.8 MB    | #####2     |  53%
# openssl-1.1.1d       | 4.8 MB    | #####4     |  55%
# openssl-1.1.1d       | 4.8 MB    | #####6     |  56%
# openssl-1.1.1d       | 4.8 MB    | #####7     |  58%
# openssl-1.1.1d       | 4.8 MB    | #####9     |  60%
# openssl-1.1.1d       | 4.8 MB    | ######1    |  62%
# openssl-1.1.1d       | 4.8 MB    | ######3    |  64%
# openssl-1.1.1d       | 4.8 MB    | ######5    |  66%
# openssl-1.1.1d       | 4.8 MB    | ######7    |  68%
# openssl-1.1.1d       | 4.8 MB    | ######9    |  70%
# openssl-1.1.1d       | 4.8 MB    | #######1   |  71%
# openssl-1.1.1d       | 4.8 MB    | #######3   |  73%
# openssl-1.1.1d       | 4.8 MB    | #######5   |  76%
# openssl-1.1.1d       | 4.8 MB    | #######7   |  78%
# openssl-1.1.1d       | 4.8 MB    | #######9   |  80%
# openssl-1.1.1d       | 4.8 MB    | ########1  |  82%
# openssl-1.1.1d       | 4.8 MB    | ########3  |  83%
# openssl-1.1.1d       | 4.8 MB    | ########5  |  85%
# openssl-1.1.1d       | 4.8 MB    | ########7  |  87%
# openssl-1.1.1d       | 4.8 MB    | ########8  |  89%
# openssl-1.1.1d       | 4.8 MB    | #########  |  91%
# openssl-1.1.1d       | 4.8 MB    | #########2 |  93%
# openssl-1.1.1d       | 4.8 MB    | #########4 |  95%
# openssl-1.1.1d       | 4.8 MB    | #########6 |  97%
# openssl-1.1.1d       | 4.8 MB    | #########9 |  99%
# openssl-1.1.1d       | 4.8 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# The system cannot find the path specified.
# The system cannot find the path specified.
# The system cannot find the path specified.
# The system cannot find the path specified.
# The system cannot find the path specified.
# The system cannot find the path specified.
# The system cannot find the path specified.

# %%
# nota pymc3 requires an old version of numpy to work
# Install a conda package in the current Jupyter kernel
# !conda install --yes --prefix {sys.prefix} numpy==1.15.0

# %%
# !conda install --yes --prefix {sys.prefix} pymc3

# %%
import pandas as pd
# we set pandas options in order to enlarge the row/columns visualization
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
import numpy as np\\\

# %%
# Import matplotlib for graphs
import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib
matplotlib.rcParams['font.size'] = 16
matplotlib.rcParams['figure.figsize'] = (9, 9)

import seaborn as sns

# Scipy helper functions
from scipy.stats import percentileofscore
from scipy import stats

# %%
# Standard ML Models for comparison
from sklearn.linear_model           import LinearRegression
from sklearn.linear_model           import ElasticNet
from sklearn.ensemble               import RandomForestRegressor
from sklearn.ensemble               import ExtraTreesRegressor
from sklearn.ensemble               import GradientBoostingRegressor
from sklearn.svm                    import SVR

from sklearn                        import metrics, svm
from sklearn.linear_model           import LogisticRegression
from sklearn.tree                   import DecisionTreeClassifier
from sklearn.neighbors              import KNeighborsClassifier
from sklearn.discriminant_analysis  import LinearDiscriminantAnalysis
from sklearn.naive_bayes            import GaussianNB
from sklearn.svm                    import SVC
from sklearn.ensemble               import RandomForestClassifier

# %%
# Splitting data into training/testing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, median_absolute_error

# Distributions
import scipy

# %%
# PyMC3 for Bayesian Inference
import pymc3 as pm

# %% [markdown]
# Open Xlsx file

# %%
xls = pd.ExcelFile('geotech1.xlsx')

# %%
sheetsls = xls.sheet_names
sheetsls
# Out:
# ['Caratt_Compl']

# %%
df1 = pd.read_excel(xls, sheetsls[0])

# %% [markdown]
# Create a DataFrame by cleaning all missing data

# %%
df=df1.copy()
df.columns=df.columns+' '+df.iloc[0,:].astype('str')
df.columns = df.columns.str.replace('nan','')
df.columns = df.columns.str.replace(' 611','')
df.columns = df.columns.str.replace("'",'^')
df.columns = df.columns.str.replace("%",'[p]')
df.columns = df.columns.str.replace("j",'ϕ')
df.drop([0,1], axis='rows', inplace=True)
df.dropna(axis='columns', thresh=5, inplace=True)
df.dropna(axis='rows', thresh=9, inplace=True)

# Select the desired columns

df=df[['Zarr0,25 m','σ^v [kPa]', 'gwet ', 'wn ', 'wopt ', 'CaCo3 ',
       'Sr [p]', 'LL [p]', 'PI [p]', 'Ic ', 'OCROED [-]', 'OCRTX [-]',
       'e0 [-]', 'Cc [-]', 'Ce [-]', '(N1)60 ',
       'cTX ', 'ϕTX ', 'c^TX ', 'ϕ^TX ', 'Cu ', 'OCR ',
       'cDSS ', 'ϕDSS ', 'CU,VANE ', 'Ep1 Mpa', 'Pl Mpa', 'Em/Pl ', 'WL.1 ', 'PI.1 ',
       'Cu,Ucs ']]

# correct the columns name

df.columns = df.columns.str.replace(" ",'_')
df.columns = df.columns.str.replace('\[-\]$','')
df.columns = df.columns.str.replace('_$','')

# correct the column type and plot statistics

df=df.astype('float')
df.describe()
# Out:
#        Zarr0,25_m   σ^v_[kPa]       gwet          wn       wopt      CaCo3     Sr_[p]      LL_[p]      PI_[p]         Ic     OCROED      OCRTX         e0         Cc         Ce      (N1)60         cTX        ϕTX       c^TX       ϕ^TX          Cu        OCR       cDSS       ϕDSS     CU,VANE    Ep1_Mpa     Pl_Mpa       Em/Pl        WL.1       PI.1      Cu,Ucs
# count  596.000000  596.000000  65.000000  148.000000   6.000000  10.000000  27.000000  136.000000  136.000000  66.000000  31.000000  26.000000  37.000000  32.000000  32.000000  268.000000   29.000000  29.000000  36.000000  36.000000   26.000000  26.000000   5.000000   5.000000   58.000000  42.000000  42.000000   42.000000   31.000000  31.000000    8.000000
# mean    20.061242  227.917911  17.852769   32.136696  19.583333  30.817000   0.961852   73.522059   43.404412   0.709168   2.712903   3.571991   1.167946   0.450594   0.081656   15.062256   46.965517  17.172414  30.833333  24.777778  186.439666   3.571991  22.600000  13.600000  253.327586  13.766667   0.721905   28.477894   78.612903  46.709677  163.668750
# std     13.811707  127.204534   0.979376   16.924352   1.734839   7.983576   0.043504   16.601636   13.290140   0.214630   1.259826   2.130319   0.233693   0.170711   0.032962    9.284723   28.031211   4.480665  24.961113   5.483019   73.251474   2.130319  16.682326   2.701851  134.300186   9.782679   0.545175   32.095831   13.169858  10.096843   68.002825
# min      0.750000   13.500000  13.340000    0.270000  16.700000  20.000000   0.810000   31.000000   11.000000  -0.250000   1.000000   1.347558   0.623000   0.098000   0.001000    5.081337    5.000000   9.000000   0.000000  17.000000   68.744449   1.347558   5.000000   9.000000   23.000000   1.900000   0.150000    7.142857   58.000000  30.000000   38.950000
# 25%      8.500000  123.843750  17.460000   27.850000  18.775000  25.647500   0.950000   65.000000   34.000000   0.614560   2.000000   2.069353   0.991000   0.316000   0.066000    9.519735   23.000000  15.000000  10.000000  19.750000  122.822503   2.069353  17.000000  14.000000  151.000000   4.425000   0.200000   12.817391   70.000000  40.000000  133.225000
# 50%     17.625000  216.000000  17.900000   35.400000  20.500000  29.500000   0.970000   73.500000   43.500000   0.711982   2.500000   2.800998   1.179000   0.425500   0.086000   12.432293   45.000000  16.000000  25.000000  24.000000  202.969366   2.800998  18.000000  14.000000  241.000000  13.600000   0.655000   14.686275   78.000000  46.000000  160.050000
# 75%     29.000000  308.500000  18.420000   44.525000  20.500000  36.092500   0.995000   83.000000   51.000000   0.853235   3.050000   4.897160   1.337000   0.594500   0.101500   17.241599   68.000000  19.000000  50.000000  28.000000  232.352324   4.897160  23.000000  15.000000  324.250000  17.975000   1.250000   24.983333   87.000000  55.000000  216.887500
# max     66.500000  609.750000  20.440000   57.200000  21.100000  42.000000   1.000000  109.000000   79.000000   1.212121   6.200000  10.490107   1.671000   0.831000   0.140000   67.681053  110.000000  29.000000  80.000000  37.000000  309.781238  10.490107  50.000000  16.000000  530.000000  43.500000   1.700000  166.470588  105.000000  65.000000  245.750000

# %% [markdown]
# From the above we notice that:
# - Water content wn should be expressed in percentage but some data are not (min value 0.27) we will drop values < 1
# - Sr should be expressed in percentage but is not (maximum value is 1)
# - OCR and OCRTx are the same column we will replace the column OCR by the mean of the 2
#
# The describe function permit to evaluate only data that permits statistics, we will then reduce the dataframe to such columns

# %%
# correct wn values 
df['wn']=df['wn'].apply(lambda x: x if (x>1) else x*100)

# joint similar data
df['OCR'] = df[["OCROED",'OCRTX']].mean(axis=1)
df['LL'] = df[["LL_[p]",'WL.1']].mean(axis=1)
df['IP'] = df[["PI_[p]",'PI.1']].mean(axis=1)
df=df.drop(columns=["PI_[p]",'PI.1',"LL_[p]",'WL.1'])
df=df.drop(columns=["OCROED",'OCRTX'])

# %%
df2=df[df.describe().columns.tolist()]

# %%
df2.columns
# Out:
# Index(['Zarr0,25_m', 'σ^v_[kPa]', 'gwet', 'wn', 'wopt', 'CaCo3', 'Sr_[p]', 'Ic', 'e0', 'Cc', 'Ce', '(N1)60', 'cTX', 'ϕTX', 'c^TX', 'ϕ^TX', 'Cu', 'OCR', 'cDSS', 'ϕDSS', 'CU,VANE', 'Ep1_Mpa', 'Pl_Mpa', 'Em/Pl', 'Cu,Ucs', 'LL', 'IP'], dtype='object')

# %% [markdown]
# - Rename the columns with suitable names
# - Drop columns that are not relevant and drop row that have less than 3 values

# %%
df2.columns=['Zarr0,25_m', 'σ^v_[kPa]', 'gwet', 'wn', 'wopt', 'CaCo3', 'Sr', 'Ic', 'e0', 'Cc', 'Ce', '(N1)60', 'c-TX', 'ϕ-Tx', 'c^Tx', 'ϕ^Tx', 'Cu-Tx', 'OCR', 'c-Dss', 'ϕ-Dss', 'CU-Vane', 'Ep1_[Mpa]', 'Pl_[Mpa]', 'Em/Pl', 'Cu-Ucs', 'LL', 'PI']
df2.dropna(axis='rows', thresh=3, inplace=True)

# %%
df2['count']=df.count(axis=1)
df2.sort_values('count', ascending=False)
# Out:
#      Zarr0,25_m  σ^v_[kPa]   gwet    wn  wopt  CaCo3   Sr        Ic     e0     Cc     Ce     (N1)60   c-TX  ϕ-Tx  c^Tx  ϕ^Tx       Cu-Tx       OCR  c-Dss  ϕ-Dss  CU-Vane  Ep1_[Mpa]  Pl_[Mpa]  Em/Pl  Cu-Ucs    LL    PI  count
# 62         4.75    82.3500  17.50  32.6   NaN    NaN  NaN  1.058621  1.084  0.425  0.101        NaN    NaN   NaN   NaN   NaN         NaN  6.200000    NaN    NaN      NaN        NaN       NaN    NaN     NaN  94.0  58.0     12
# 632       16.75   223.2500  17.11  56.3   NaN    NaN  1.0       NaN    NaN    NaN    NaN        NaN  110.0  14.0  80.0  28.0  156.454585  2.015677    NaN    NaN      NaN        NaN       NaN    NaN     NaN   NaN   NaN     12
# 630       10.75   178.6250  18.38  39.4   NaN    NaN  1.0       NaN    NaN    NaN    NaN        NaN   40.0  22.0  30.0  30.0  157.558352  2.687194    NaN    NaN      NaN        NaN       NaN    NaN     NaN   NaN   NaN     12
# 532       46.75   447.6875  18.20  32.9   NaN    NaN  NaN  0.281818  1.008  0.321  0.013        NaN    NaN   NaN   NaN   NaN         NaN  1.300000    NaN    NaN      NaN        NaN       NaN    NaN     NaN  36.0  11.0     12
# 531       41.00   403.8125  16.82  55.1   NaN    NaN  NaN  0.678723  1.536  0.627  0.140        NaN    NaN   NaN   NaN   NaN         NaN  1.600000    NaN    NaN      NaN        NaN       NaN    NaN     NaN  87.0  47.0     12
# ..          ...        ...    ...   ...   ...    ...  ...       ...    ...    ...    ...        ...    ...   ...   ...   ...         ...       ...    ...    ...      ...        ...       ...    ...     ...   ...   ...    ...
# 295       32.00   300.0000    NaN   NaN   NaN    NaN  NaN       NaN    NaN    NaN    NaN  12.008622    NaN   NaN   NaN   NaN         NaN       NaN    NaN    NaN      NaN        NaN       NaN    NaN     NaN   NaN   NaN      4
# 294       29.00   277.5000    NaN   NaN   NaN    NaN  NaN       NaN    NaN    NaN    NaN  12.485971    NaN   NaN   NaN   NaN         NaN       NaN    NaN    NaN      NaN        NaN       NaN    NaN     NaN   NaN   NaN      4
# 293       27.00   262.5000    NaN   NaN   NaN    NaN  NaN       NaN    NaN    NaN    NaN  15.894366    NaN   NaN   NaN   NaN         NaN       NaN    NaN    NaN      NaN        NaN       NaN    NaN     NaN   NaN   NaN      4
# 292       25.00   247.5000    NaN   NaN   NaN    NaN  NaN       NaN    NaN    NaN    NaN  12.591483    NaN   NaN   NaN   NaN         NaN       NaN    NaN    NaN      NaN        NaN       NaN    NaN     NaN   NaN   NaN      4
# 652       44.25   436.8750    NaN   NaN   NaN    NaN  NaN       NaN    NaN    NaN    NaN        NaN    NaN   NaN   NaN   NaN         NaN       NaN    NaN    NaN      NaN        NaN       NaN    NaN   211.9   NaN   NaN      4
#
# [588 rows x 28 columns]

# %% [markdown]
# The dataframe is now ordered. The next step is a population routine that will replace all NaN values by regressed values.
# Let's order the parameters by count. This will allow us to decide which parameters are going to lead the populate routine.

# %%
dfd=df2.describe()
dfdt = dfd.transpose()
dfdt.sort_values('count', ascending=False)
# Out:
#             count        mean         std        min         25%         50%         75%         max
# Zarr0,25_m  588.0   20.176871   13.829423   0.750000    8.500000   18.000000   29.000000   66.500000
# σ^v_[kPa]   588.0  229.408291  127.134431  13.500000  125.750000  219.000000  310.000000  609.750000
# count       588.0    5.448980    2.426946   4.000000    4.000000    4.000000    6.000000   12.000000
# (N1)60      268.0   15.062256    9.284723   5.081337    9.519735   12.432293   17.241599   67.681053
# PI          167.0   44.017964   12.795647  11.000000   35.000000   44.000000   51.000000   79.000000
# LL          167.0   74.467066   16.106866  31.000000   65.500000   74.000000   83.000000  109.000000
# wn          148.0   39.515541    8.598843  20.600000   32.900000   38.250000   45.350000   57.300000
# Ic           66.0    0.709168    0.214630  -0.250000    0.614560    0.711982    0.853235    1.212121
# gwet         65.0   17.852769    0.979376  13.340000   17.460000   17.900000   18.420000   20.440000
# CU-Vane      58.0  253.327586  134.300186  23.000000  151.000000  241.000000  324.250000  530.000000
# OCR          57.0    3.104768    1.750037   1.000000    2.000000    2.600000    3.372604   10.490107
# Em/Pl        42.0   28.477894   32.095831   7.142857   12.817391   14.686275   24.983333  166.470588
# Pl_[Mpa]     42.0    0.721905    0.545175   0.150000    0.200000    0.655000    1.250000    1.700000
# Ep1_[Mpa]    42.0   13.766667    9.782679   1.900000    4.425000   13.600000   17.975000   43.500000
# e0           37.0    1.167946    0.233693   0.623000    0.991000    1.179000    1.337000    1.671000
# ϕ^Tx         36.0   24.777778    5.483019  17.000000   19.750000   24.000000   28.000000   37.000000
# c^Tx         36.0   30.833333   24.961113   0.000000   10.000000   25.000000   50.000000   80.000000
# Ce           32.0    0.081656    0.032962   0.001000    0.066000    0.086000    0.101500    0.140000
# Cc           32.0    0.450594    0.170711   0.098000    0.316000    0.425500    0.594500    0.831000
# ϕ-Tx         29.0   17.172414    4.480665   9.000000   15.000000   16.000000   19.000000   29.000000
# c-TX         29.0   46.965517   28.031211   5.000000   23.000000   45.000000   68.000000  110.000000
# Sr           27.0    0.961852    0.043504   0.810000    0.950000    0.970000    0.995000    1.000000
# Cu-Tx        26.0  186.439666   73.251474  68.744449  122.822503  202.969366  232.352324  309.781238
# CaCo3        10.0   30.817000    7.983576  20.000000   25.647500   29.500000   36.092500   42.000000
# Cu-Ucs        8.0  163.668750   68.002825  38.950000  133.225000  160.050000  216.887500  245.750000
# wopt          6.0   19.583333    1.734839  16.700000   18.775000   20.500000   20.500000   21.100000
# c-Dss         5.0   22.600000   16.682326   5.000000   17.000000   18.000000   23.000000   50.000000
# ϕ-Dss         5.0   13.600000    2.701851   9.000000   14.000000   14.000000   15.000000   16.000000

# %% [markdown]
# Create a dataframe 'dfo' that is ordered according to the most relevant parameters

# %%
dfo = df[dfdt.sort_values('count', ascending=False).index.tolist()].sort_values('count',ascending=False)
dfo
# Out:
#      Zarr0,25_m  σ^v_[kPa]  count     (N1)60    PI    LL    wn        Ic   gwet  CU-Vane       OCR  Em/Pl  Pl_[Mpa]  Ep1_[Mpa]     e0  ϕ^Tx  c^Tx     Ce     Cc  ϕ-Tx   c-TX   Sr       Cu-Tx  CaCo3  Cu-Ucs  wopt  c-Dss  ϕ-Dss
# 62         4.75    82.3500     11        NaN  58.0  94.0  32.6  1.058621  17.50      NaN  6.200000    NaN       NaN        NaN  1.084   NaN   NaN  0.101  0.425   NaN    NaN  NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 632       16.75   223.2500     11        NaN   NaN   NaN  56.3       NaN  17.11      NaN  2.015677    NaN       NaN        NaN    NaN  28.0  80.0    NaN    NaN  14.0  110.0  1.0  156.454585    NaN     NaN   NaN    NaN    NaN
# 630       10.75   178.6250     11        NaN   NaN   NaN  39.4       NaN  18.38      NaN  2.687194    NaN       NaN        NaN    NaN  30.0  30.0    NaN    NaN  22.0   40.0  1.0  157.558352    NaN     NaN   NaN    NaN    NaN
# 532       46.75   447.6875     11        NaN  11.0  36.0  32.9  0.281818  18.20      NaN  1.300000    NaN       NaN        NaN  1.008   NaN   NaN  0.013  0.321   NaN    NaN  NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 531       41.00   403.8125     11        NaN  47.0  87.0  55.1  0.678723  16.82      NaN  1.600000    NaN       NaN        NaN  1.536   NaN   NaN  0.140  0.627   NaN    NaN  NaN         NaN    NaN     NaN   NaN    NaN    NaN
# ..          ...        ...    ...        ...   ...   ...   ...       ...    ...      ...       ...    ...       ...        ...    ...   ...   ...    ...    ...   ...    ...  ...         ...    ...     ...   ...    ...    ...
# 295       32.00   300.0000      3  12.008622   NaN   NaN   NaN       NaN    NaN      NaN       NaN    NaN       NaN        NaN    NaN   NaN   NaN    NaN    NaN   NaN    NaN  NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 294       29.00   277.5000      3  12.485971   NaN   NaN   NaN       NaN    NaN      NaN       NaN    NaN       NaN        NaN    NaN   NaN   NaN    NaN    NaN   NaN    NaN  NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 293       27.00   262.5000      3  15.894366   NaN   NaN   NaN       NaN    NaN      NaN       NaN    NaN       NaN        NaN    NaN   NaN   NaN    NaN    NaN   NaN    NaN  NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 292       25.00   247.5000      3  12.591483   NaN   NaN   NaN       NaN    NaN      NaN       NaN    NaN       NaN        NaN    NaN   NaN   NaN    NaN    NaN   NaN    NaN  NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 652       44.25   436.8750      3        NaN   NaN   NaN   NaN       NaN    NaN      NaN       NaN    NaN       NaN        NaN    NaN   NaN   NaN    NaN    NaN   NaN    NaN  NaN         NaN    NaN   211.9   NaN    NaN    NaN
#
# [588 rows x 28 columns]

# %%
dfg=dfo.groupby('Zarr0,25_m').mean()
print('The shape of the new dataframe is:',dfg.shape)
dfg
# Out:
# The shape of the new dataframe is: (153, 27)
#              σ^v_[kPa]      count     (N1)60         PI          LL         wn        Ic     gwet     CU-Vane       OCR       Em/Pl  Pl_[Mpa]  Ep1_[Mpa]      e0  ϕ^Tx   c^Tx      Ce     Cc  ϕ-Tx   c-TX    Sr       Cu-Tx  CaCo3  Cu-Ucs  wopt  c-Dss  ϕ-Dss
# Zarr0,25_m
# 0.75         13.500000   6.000000        NaN  34.000000   57.000000  28.000000  0.852941      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 1.50         27.000000   3.000000   8.500000        NaN         NaN  30.000000       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN  20.5    NaN    NaN
# 1.75         31.500000   3.000000        NaN        NaN         NaN        NaN       NaN      NaN   90.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 2.00         34.333333   3.083333  27.329827  60.000000   92.000000  30.000000       NaN      NaN  241.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN  16.7    NaN    NaN
# 2.50         44.742857   3.571429  28.791405  46.000000   77.000000  27.400000       NaN  19.0600  241.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 2.75         42.000000   5.000000        NaN  44.500000   69.000000  27.000000  0.931818      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 3.00         54.000000   3.000000  23.182810        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN  20.5    NaN    NaN
# 3.25         57.825000   5.500000  14.244567  40.000000   67.500000        NaN       NaN      NaN         NaN       NaN    9.657468  0.993333   9.400000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 3.50         59.183333   4.666667  26.413204  41.000000   70.000000  35.200000       NaN  17.7525         NaN  5.730159         NaN       NaN        NaN     NaN  19.5  31.25     NaN    NaN   9.0   50.0  0.93   68.744449    NaN     NaN   NaN   50.0    9.0
# 3.75         65.250000   9.500000        NaN  41.000000   70.000000  32.700000  0.878049  19.2400         NaN  8.145053         NaN       NaN        NaN  1.0850  23.0  10.00  0.0700  0.261   NaN    NaN  0.97  116.292860    NaN     NaN   NaN    NaN    NaN
# 4.00         66.755556   4.222222  37.185737  31.666667   59.000000  25.000000  1.212121      NaN         NaN       NaN         NaN       NaN        NaN  1.0785  26.0   7.00     NaN    NaN  14.0   18.0   NaN         NaN  42.00     NaN  21.1   18.0   14.0
# 4.25         75.900000   4.000000        NaN  39.000000   68.000000  32.000000  0.615385      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 4.50         79.142857   3.142857  21.459846  65.000000  102.000000        NaN       NaN      NaN  201.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN  20.5    NaN    NaN
# 4.75         83.275000   7.500000        NaN  58.000000   94.000000  32.833333  1.058621  18.1300  211.000000  6.023977         NaN       NaN        NaN  1.0840  24.0   1.00  0.1010  0.425  19.0    6.0  0.96   70.242381    NaN     NaN   NaN    NaN    NaN
# 5.00         82.078571   3.500000  18.183791  65.000000  102.000000  37.700000       NaN  18.7900         NaN       NaN         NaN       NaN        NaN     NaN  19.0  15.00     NaN    NaN  16.0   17.0   NaN         NaN    NaN     NaN   NaN   17.0   16.0
# 5.25         94.050000  10.500000        NaN  65.000000  102.000000  34.350000  1.024615  18.8100         NaN  5.688034         NaN       NaN        NaN  0.9740  19.0  15.00  0.0990  0.301  16.0   17.0  0.95   77.192537    NaN     NaN   NaN    NaN    NaN
# 5.50         64.000000   6.000000        NaN  43.000000   69.000000  40.000000  0.674419      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 6.00        103.440000   3.900000  15.010777  57.000000   90.000000  43.000000  0.771930      NaN  151.000000       NaN         NaN       NaN        NaN  0.9320  27.0   0.00     NaN    NaN  15.0    5.0   NaN         NaN    NaN     NaN  18.2    5.0   15.0
# 6.25         91.250000   3.500000        NaN  61.000000   87.000000        NaN       NaN      NaN  241.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 6.50        112.150000   5.454545  14.175129  55.000000   82.000000  31.260000  0.936108  18.3250  301.000000  6.656085         NaN       NaN        NaN  0.7800  25.0  11.50  0.0800  0.290  16.0   24.0  0.97  103.328023    NaN     NaN   NaN   23.0   14.0
# 6.75        112.700000   4.800000        NaN  33.000000   64.000000  39.050000       NaN  18.1450  301.000000       NaN         NaN       NaN        NaN     NaN  31.5  12.50     NaN    NaN  29.0   23.0  0.95         NaN    NaN     NaN   NaN    NaN    NaN
# 7.00        114.850000   6.750000        NaN  23.000000   48.666667  39.350000  0.684848  18.4200         NaN  3.364117         NaN       NaN        NaN  1.1630  26.0  20.00  0.0860  0.343   NaN    NaN  0.94   81.285284    NaN     NaN   NaN    NaN    NaN
# 7.25        101.600000   5.750000        NaN  64.500000   96.500000  36.000000  0.972222      NaN         NaN       NaN   16.917894  0.876667  14.900000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 7.50        133.200000   3.000000        NaN        NaN         NaN  31.000000       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 7.75        123.325000   7.500000        NaN  20.000000   44.000000  33.266667  0.565000  18.5300  256.000000  3.262903         NaN       NaN        NaN  1.0040  24.0  72.00  0.0170  0.355  22.0   75.0  0.98  142.411429    NaN     NaN   NaN    NaN    NaN
# 8.00        127.088889   3.222222  13.607324  45.000000   79.000000        NaN       NaN      NaN   50.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 8.25        128.337500   6.500000  50.392159  51.500000   79.500000  45.133333  0.678382  17.9000         NaN  5.182288         NaN       NaN        NaN     NaN  20.0  32.00     NaN    NaN  11.0   45.0  0.96  161.698689    NaN     NaN   NaN    NaN    NaN
# 8.50        139.571429   3.000000  25.590033        NaN         NaN  32.000000       NaN      NaN  121.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 9.00        150.285714   3.142857  11.723698  21.000000   46.000000        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 9.25         94.000000   3.000000        NaN        NaN         NaN        NaN       NaN      NaN  271.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 9.50        170.550000   4.000000        NaN  21.000000   46.000000  33.100000       NaN  18.0000         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 9.75        123.833333   6.666667  20.934085  40.000000   68.000000  37.950000  0.775000  17.9700         NaN  6.083265         NaN       NaN        NaN     NaN  29.0  10.00     NaN    NaN  21.0   20.0  0.97  112.175818    NaN     NaN   NaN    NaN    NaN
# 10.00       148.633333   5.000000  20.301632  33.333333   61.000000  35.050000  0.614286      NaN         NaN  3.000000   12.941176  0.170000   2.200000  1.0270   NaN    NaN  0.0330  0.235   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 10.25       100.562500  11.000000        NaN  40.000000   68.000000  41.800000  0.655000  18.0100         NaN  3.400000         NaN       NaN        NaN  1.1650   NaN    NaN  0.0830  0.296   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 10.50       168.052083   4.666667  14.135809  39.000000   69.000000  35.600000  0.856410  18.7300         NaN  2.600000         NaN       NaN        NaN  0.9910   NaN    NaN  0.0660  0.328   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 10.75       148.125000   5.000000        NaN        NaN         NaN  39.400000       NaN  18.3800  226.000000  2.687194         NaN       NaN        NaN     NaN  30.0  30.00     NaN    NaN  22.0   40.0  1.00  157.558352    NaN  140.05   NaN    NaN    NaN
# 11.00       176.666667   3.000000  10.997606        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 11.25       150.343750   6.250000        NaN  53.000000   79.666667  45.000000  0.810127      NaN         NaN       NaN   13.403214  1.066667  14.000000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 11.50       206.250000   3.000000  17.241599        NaN         NaN  22.000000       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 12.00       170.700000   3.200000  13.801237  40.000000   74.000000        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 12.25       145.625000   5.000000        NaN  44.000000   73.500000  47.500000  0.596023      NaN  301.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 12.50       165.718750   3.000000  23.309386        NaN         NaN        NaN       NaN      NaN   61.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 12.75       144.062500  11.000000        NaN  36.000000   66.000000  49.000000  0.472222  18.0100         NaN  3.000000         NaN       NaN        NaN  1.2760   NaN    NaN  0.0950  0.567   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 13.00       123.750000   4.500000        NaN  24.000000   46.000000  36.000000  0.416667      NaN  121.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 13.25       221.375000   3.000000  51.590759        NaN         NaN  30.000000       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 13.50       198.781250   8.500000        NaN  34.000000   65.000000  44.900000  0.591176  17.8300         NaN  2.800000         NaN       NaN        NaN  1.2350   NaN    NaN  0.0860  0.535   NaN    NaN   NaN         NaN  20.00     NaN   NaN    NaN    NaN
# 13.75       160.750000   5.250000        NaN        NaN         NaN  49.950000       NaN  16.8950  181.000000  2.744853         NaN       NaN        NaN     NaN  24.0  50.00     NaN    NaN  18.0   68.0  1.00  179.770675    NaN     NaN   NaN    NaN    NaN
# 14.00       182.468750   4.000000  10.149297  36.750000   60.250000  52.200000  0.701961  17.3800  294.000000  4.000000         NaN       NaN        NaN  1.3590  19.0  80.00  0.0990  0.456   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 14.25       189.421875   5.750000        NaN  31.000000   58.333333  32.750000  0.882353  17.9000         NaN  4.041775         NaN       NaN        NaN     NaN  19.0  80.00     NaN    NaN   NaN    NaN  0.92  234.145877    NaN     NaN   NaN    NaN    NaN
# 14.50       190.050000   3.400000  10.856259  51.000000   83.000000        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 15.00       219.409091   3.363636  15.200920  35.000000   70.000000  38.000000       NaN      NaN         NaN       NaN   11.764706  0.170000   2.000000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 15.25       176.125000   5.000000        NaN  40.000000   70.000000        NaN       NaN      NaN   90.000000       NaN   15.541925  1.275000  20.150000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 15.50       188.270833   3.666667  29.168112  50.000000   80.000000  41.700000       NaN  13.3400         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 15.75       182.453125   4.250000        NaN  46.666667   76.666667  50.000000  0.421053      NaN         NaN       NaN         NaN       NaN        NaN  1.1820   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 16.00       164.906250   4.250000  13.288341  46.000000   77.000000  41.000000  0.695652      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 16.50       220.648438   4.250000  16.740082  35.000000   70.000000  46.200000  0.520000  17.1900         NaN  2.200000         NaN       NaN        NaN  1.4290   NaN    NaN  0.0660  0.546   NaN    NaN   NaN         NaN    NaN  124.75   NaN    NaN    NaN
# 16.75       207.166667   7.666667        NaN  42.000000   71.000000  43.100000  0.806122  17.1100         NaN  2.015677         NaN       NaN        NaN     NaN  28.0  80.00     NaN    NaN  14.0  110.0  1.00  156.454585    NaN     NaN   NaN    NaN    NaN
# 17.00       224.977273   4.000000  10.844737  33.000000   58.000000  28.000000  0.878788  18.6100   81.000000  3.372604         NaN       NaN        NaN     NaN  19.0  65.00     NaN    NaN  14.0   75.0  0.87  263.541853    NaN     NaN   NaN    NaN    NaN
# 17.25       250.437500  10.000000        NaN  33.000000   58.000000  33.500000  0.742424      NaN         NaN  3.000000         NaN       NaN        NaN  0.8680   NaN    NaN  0.0750  0.242   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 18.00       219.000000   3.090909  10.264943  40.000000   74.000000  35.000000       NaN      NaN  365.666667       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 18.25       205.000000   6.000000        NaN  42.000000   69.000000  49.500000  0.463131      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 18.50       223.666667   4.166667  12.001375  49.000000   79.500000  44.600000  0.903846  16.7000   70.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN  25.00     NaN   NaN    NaN    NaN
# 18.75       188.125000   6.000000        NaN  31.000000   77.000000  55.000000  0.709677      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 19.00       225.500000   5.666667        NaN  40.000000   74.000000  54.200000  0.495000      NaN  211.000000  3.000000         NaN       NaN        NaN  1.5300   NaN    NaN  0.1030  0.592   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 19.25       230.458333   5.666667        NaN  40.000000   70.000000        NaN       NaN      NaN  471.000000       NaN   14.387363  1.350000  19.300000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 19.50       246.000000   6.000000        NaN  58.000000   89.000000  48.400000       NaN      NaN         NaN       NaN   15.266667  1.500000  22.900000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 19.75       245.000000  11.000000        NaN        NaN         NaN  52.700000       NaN  17.0700         NaN  2.857143         NaN       NaN        NaN     NaN  31.0  50.00     NaN    NaN  18.0   80.0  0.97  226.971663    NaN     NaN   NaN    NaN    NaN
# 20.00       242.487500   4.200000  11.286975  61.800000   99.200000  48.400000  0.845902  17.0300  211.000000  3.100000   44.130435  0.215000  10.000000  1.3970   NaN    NaN  0.1180  0.638   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 20.50       236.312500   4.500000  15.176955  43.000000   67.500000  34.000000  0.755556      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 21.00       261.750000   3.000000   9.878959        NaN         NaN        NaN       NaN      NaN  196.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 21.50       283.250000   3.000000        NaN        NaN         NaN  30.000000       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 22.00       234.000000   3.250000   6.836795  40.000000   73.000000        NaN       NaN      NaN  211.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN  30.00     NaN   NaN    NaN    NaN
# 22.50       256.430556   4.111111  14.906200  30.000000   60.000000  41.666667       NaN  17.5800  471.000000  2.252464         NaN       NaN        NaN     NaN  27.0  25.00     NaN    NaN  17.0   55.0  1.00  204.023261    NaN  180.05   NaN    NaN    NaN
# 23.00       281.664062   4.000000   9.272550  30.000000   60.000000  45.300000  0.490000  17.4300         NaN  2.300000         NaN       NaN        NaN  1.2920   NaN    NaN  0.0560  0.602   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 23.25       242.500000   6.000000        NaN  65.000000   95.000000        NaN       NaN      NaN         NaN       NaN   14.014815  1.300000  18.200000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 23.50       288.375000   5.000000        NaN  50.000000   78.000000        NaN       NaN      NaN         NaN       NaN   21.407407  1.350000  28.900000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN  42.00     NaN   NaN    NaN    NaN
# 24.00       287.625000   3.000000  11.861167        NaN         NaN  38.000000       NaN      NaN  318.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 24.25       205.562500  11.000000        NaN  60.000000   87.000000  35.800000  0.853333  19.3900         NaN  2.500000         NaN       NaN        NaN  0.9260   NaN    NaN  0.0800  0.330   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 24.50       238.750000   3.000000  15.932512        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 25.00       279.300000   4.600000  13.535443  46.000000   81.000000        NaN       NaN      NaN         NaN       NaN   17.666667  0.190000   3.300000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 25.50       263.750000   6.166667        NaN  42.800000   72.200000  39.575000  0.813333  17.6100         NaN  2.928008         NaN       NaN        NaN     NaN  31.0  15.00     NaN    NaN  21.0   35.0  0.95  225.913833  35.80     NaN   NaN    NaN    NaN
# 25.75       265.125000   9.000000        NaN  42.000000   68.000000  41.500000  0.764286  18.2350         NaN  2.002590         NaN       NaN        NaN     NaN  28.0  30.00     NaN    NaN  19.0   52.0  1.00  201.915471    NaN     NaN   NaN    NaN    NaN
# 26.00       312.072917   4.750000  10.878942  49.000000   77.250000  44.233333  0.687913  17.6350   88.000000  2.000000         NaN       NaN        NaN  1.0335   NaN    NaN  0.1025  0.475   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 26.25       245.875000   6.000000        NaN  16.000000   38.000000  42.000000 -0.250000      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 26.50       282.887500   3.200000  12.589085        NaN         NaN  36.500000       NaN  18.1800  471.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 27.00       291.000000   3.000000  13.044276        NaN         NaN        NaN       NaN      NaN  471.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 27.25       284.000000   7.000000        NaN  45.000000   74.000000        NaN       NaN      NaN         NaN       NaN   18.251634  1.366667  26.166667     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 27.50       328.250000   3.000000        NaN        NaN         NaN  32.000000       NaN      NaN  294.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 28.00       247.000000   3.000000        NaN        NaN         NaN        NaN       NaN      NaN  297.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 28.50       313.125000   3.500000  15.342626  47.000000   87.000000  52.600000       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN  136.05   NaN    NaN    NaN
# 28.75       312.350000  11.000000        NaN        NaN         NaN  57.300000       NaN  16.8300         NaN  1.920922         NaN       NaN        NaN     NaN  24.0  60.00     NaN    NaN  17.0   65.0  0.98  210.624697    NaN     NaN   NaN    NaN    NaN
# 29.00       327.131250   3.800000  12.975460  47.000000   87.000000  52.600000  0.731915  17.0400  177.000000  2.000000         NaN       NaN        NaN  1.4630   NaN    NaN  0.0910  0.718   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 30.00       319.090909   3.363636  10.875583  47.000000   87.000000        NaN       NaN      NaN  368.000000       NaN    9.500000  0.200000   1.900000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 30.50       333.416667   4.333333   9.807975  31.000000   58.000000        NaN       NaN      NaN         NaN       NaN   84.375000  0.160000  13.500000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 31.00       325.791667   4.333333  11.463275  45.500000   70.500000  50.000000  0.468085      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 31.25       327.331250   7.000000        NaN  41.666667   70.666667  50.200000  0.427273  17.5800   23.000000  2.000000   19.926667  1.375000  28.100000  1.3480   NaN    NaN  0.1190  0.652   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 31.50       261.250000   3.000000        NaN        NaN         NaN        NaN       NaN      NaN  471.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 31.75       335.375000  11.000000        NaN        NaN         NaN  31.200000       NaN  19.3300         NaN  2.236303         NaN       NaN        NaN     NaN  19.0  60.00     NaN    NaN  16.0   85.0  0.99  255.396616    NaN     NaN   NaN    NaN    NaN
# 32.00       336.817308   3.769231  11.552841  31.000000   58.000000  33.200000  0.800000  18.9100  241.000000  2.000000         NaN       NaN        NaN  0.9370   NaN    NaN  0.0480  0.293   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 32.50       354.750000   3.000000   9.615805        NaN         NaN  35.000000       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 33.00       350.277778   3.000000  11.900691        NaN         NaN        NaN       NaN      NaN  235.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 33.50       355.500000   5.000000        NaN  61.000000   96.000000  41.700000       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 34.00       303.500000   3.000000   9.380449        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 34.50       325.687500   4.250000   5.081337  52.500000   84.000000  44.400000       NaN      NaN   68.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN  29.00  245.75   NaN    NaN    NaN
# 34.75       333.666667   9.333333        NaN  52.500000   84.000000  42.966667  0.775987  17.6700         NaN  2.270056         NaN       NaN        NaN  1.2750  17.0  50.00  0.1100  0.523  15.0   60.0  0.98  272.330342    NaN     NaN   NaN    NaN    NaN
# 35.00       366.600000   3.400000  10.662619  61.000000   96.000000        NaN       NaN      NaN  241.000000       NaN   20.000000  0.150000   3.000000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 35.50       345.500000   5.000000        NaN  48.000000   81.000000        NaN       NaN      NaN  241.000000       NaN   92.500000  0.160000  14.800000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 36.00       340.000000   3.000000  12.354435        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 36.50       298.750000   3.000000        NaN        NaN         NaN        NaN       NaN      NaN  241.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 36.75       379.437500   6.666667        NaN  60.000000   97.000000  47.100000  0.800000  17.4800         NaN  1.000000         NaN       NaN        NaN  1.3450   NaN    NaN  0.1090  0.426   NaN    NaN   NaN         NaN  27.59   38.95   NaN    NaN    NaN
# 37.50       354.375000   4.000000   9.810375  65.000000  109.000000  55.600000       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 37.75       380.281250  11.000000        NaN  65.000000  109.000000  51.900000  0.821538  16.7700         NaN  2.276316         NaN       NaN        NaN  1.6710  23.0  35.00  0.0960  0.831  16.0   40.0  1.00  270.204385    NaN     NaN   NaN    NaN    NaN
# 38.00       359.333333   3.000000  10.865324        NaN         NaN        NaN       NaN      NaN  530.000000       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 39.00       362.500000   3.000000   7.803182        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 39.50       321.250000   3.000000  22.656707        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 40.00       405.333333   5.666667   9.904544  56.000000   94.000000        NaN       NaN      NaN         NaN       NaN   56.599265  0.165000   9.200000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 40.50       401.250000   6.666667        NaN  52.000000   91.000000  54.000000       NaN  17.2000         NaN  1.493466         NaN       NaN        NaN     NaN  36.0   0.00     NaN    NaN  22.0   15.0  0.99  221.499203  20.59  231.85   NaN    NaN    NaN
# 41.00       390.656250   7.000000   6.117265  47.000000   87.000000  55.100000  0.678723  16.8200         NaN  1.600000         NaN       NaN        NaN  1.5360   NaN    NaN  0.1400  0.627   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 42.00       416.750000   4.000000  12.641069  76.000000  109.000000  33.000000       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 43.50       423.500000   5.000000        NaN  30.000000   59.000000  39.300000       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 43.75       424.625000  11.000000        NaN        NaN         NaN  32.000000       NaN  19.0100         NaN  2.119517         NaN       NaN        NaN     NaN  35.0   0.00     NaN    NaN  26.0   75.0  0.93  309.781238    NaN     NaN   NaN    NaN    NaN
# 44.00       421.078125   5.000000   8.707497  30.000000   59.000000  39.300000  0.656667  18.1500         NaN  2.000000         NaN       NaN        NaN  1.1100   NaN    NaN  0.0590  0.367   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 44.25       436.687500   6.666667        NaN  38.000000   71.000000  44.350000  0.636842  17.2800         NaN  2.100000         NaN       NaN        NaN  1.3370   NaN    NaN  0.0780  0.659   NaN    NaN   NaN         NaN  36.19  211.90   NaN    NaN    NaN
# 44.50       438.375000  11.000000        NaN        NaN         NaN  45.500000       NaN  17.8100         NaN  1.938979         NaN       NaN        NaN     NaN  21.0  25.00     NaN    NaN  15.0   38.0  1.00  297.827151    NaN     NaN   NaN    NaN    NaN
# 45.00       431.166667   4.333333  13.313071  30.000000   59.000000        NaN       NaN      NaN         NaN       NaN   22.000000  0.200000   4.400000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 45.50       446.250000   7.000000        NaN  38.000000   71.000000        NaN       NaN      NaN         NaN       NaN  166.470588  0.170000  28.300000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 46.50       445.625000   8.000000        NaN  11.000000   36.000000  32.550000       NaN  17.5000         NaN  1.347558         NaN       NaN        NaN     NaN  33.0  20.00     NaN    NaN  15.0   95.0  0.81  226.100633    NaN     NaN   NaN    NaN    NaN
# 46.75       447.687500  11.000000        NaN  11.000000   36.000000  32.900000  0.281818  18.2000         NaN  1.300000         NaN       NaN        NaN  1.0080   NaN    NaN  0.0130  0.321   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 47.00       452.500000   3.000000   8.846649        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 48.00       462.312500   4.000000   9.236035  42.000000   72.000000  31.900000       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 49.50       475.187500   4.000000   9.922499  47.000000   81.000000  20.600000       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 49.75       470.187500   8.000000        NaN        NaN         NaN  20.600000       NaN  20.4400         NaN  1.000000         NaN       NaN        NaN  0.6230   NaN    NaN  0.0010  0.098   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 50.00       479.500000   5.000000  15.483989  47.000000   81.000000        NaN       NaN      NaN         NaN       NaN   12.000000  0.250000   3.000000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 50.50       482.250000   7.000000        NaN  42.000000   72.000000        NaN       NaN      NaN         NaN       NaN   12.800000  0.250000   3.200000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 51.00       482.500000   3.000000  10.370834        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 52.00       495.000000   3.000000  31.162332        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 52.50       498.250000   4.000000  14.107378  47.000000   81.000000  45.000000       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 52.75       492.312500  11.000000        NaN  47.000000   81.000000  45.000000  0.765957  17.5000         NaN  1.400000         NaN       NaN        NaN  1.2790   NaN    NaN  0.1310  0.612   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 53.00       496.500000   3.000000  15.335607        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 54.00       505.000000   3.000000  11.018661        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 54.50       519.750000   3.000000  16.509003        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 55.00       516.250000   5.000000  20.164825  47.000000   81.000000        NaN       NaN      NaN         NaN       NaN   47.600000  0.250000  11.900000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 55.50       520.500000   5.000000        NaN        NaN         NaN        NaN       NaN      NaN         NaN       NaN   87.142857  0.210000  18.300000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 56.00       520.000000   3.000000  38.222184        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 56.50       534.750000   3.000000  15.419192        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 57.00       527.500000   3.000000  34.068292        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 58.50       549.750000   3.000000  25.768060        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 59.00       542.500000   3.000000  18.710583        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 59.50       555.750000   5.000000        NaN        NaN         NaN        NaN       NaN      NaN         NaN       NaN   27.600000  0.250000   6.900000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 60.00       555.000000   5.000000        NaN        NaN         NaN        NaN       NaN      NaN         NaN       NaN   13.478261  0.230000   3.100000     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 61.50       572.250000   3.000000  20.701967        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 63.00       583.500000   3.000000  26.651854        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN
# 66.50       609.750000   3.000000  20.055274        NaN         NaN        NaN       NaN      NaN         NaN       NaN         NaN       NaN        NaN     NaN   NaN    NaN     NaN    NaN   NaN    NaN   NaN         NaN    NaN     NaN   NaN    NaN    NaN

# %% [markdown]
# ## Filling missing data by interpolation
#
# One of the possibility to populate missing data is by means of interpolations. SInce we have lots of missing data we are obliged to start by using an unsupervised method of filling. Wi will do this for the following paramters:
#
# - Atterberg Limits (LL,IP)
# - Water content

# %%
dfg['PI'].interpolate(method ='linear', limit_direction ='forward', inplace=True)
dfg['LL'].interpolate(method ='linear', limit_direction ='forward', inplace=True)
dfg['wn'].interpolate(method ='linear', limit_direction ='forward', inplace=True)
dfg.head()
# Out:
#             σ^v_[kPa]     count     (N1)60         PI         LL    wn        Ic   gwet  CU-Vane  OCR  Em/Pl  Pl_[Mpa]  Ep1_[Mpa]  e0  ϕ^Tx  c^Tx  Ce  Cc  ϕ-Tx  c-TX  Sr  Cu-Tx  CaCo3  Cu-Ucs  wopt  c-Dss  ϕ-Dss   (N1)60_R
# Zarr0,25_m
# 0.75        13.500000  6.000000        NaN  34.000000  57.000000  28.0  0.852941    NaN      NaN  NaN    NaN       NaN        NaN NaN   NaN   NaN NaN NaN   NaN   NaN NaN    NaN    NaN     NaN   NaN    NaN    NaN  26.886468
# 1.50        27.000000  3.000000   8.500000  42.666667  68.666667  30.0       NaN    NaN      NaN  NaN    NaN       NaN        NaN NaN   NaN   NaN NaN NaN   NaN   NaN NaN    NaN    NaN     NaN  20.5    NaN    NaN   8.500000
# 1.75        31.500000  3.000000        NaN  51.333333  80.333333  30.0       NaN    NaN     90.0  NaN    NaN       NaN        NaN NaN   NaN   NaN NaN NaN   NaN   NaN NaN    NaN    NaN     NaN   NaN    NaN    NaN        NaN
# 2.00        34.333333  3.083333  27.329827  60.000000  92.000000  30.0       NaN    NaN    241.0  NaN    NaN       NaN        NaN NaN   NaN   NaN NaN NaN   NaN   NaN NaN    NaN    NaN     NaN  16.7    NaN    NaN  27.329827
# 2.50        44.742857  3.571429  28.791405  46.000000  77.000000  27.4       NaN  19.06    241.0  NaN    NaN       NaN        NaN NaN   NaN   NaN NaN NaN   NaN   NaN NaN    NaN    NaN     NaN   NaN    NaN    NaN  28.791405

# %% [markdown]
# ## Final dataframe setting up
#
# The final dataframe will be based on:
#
# - Insitu stress s'v
# - Atterberg Limits (LL,IP)
# - Water content
# - Corrected Nspt --> (N1)60
# - Undrained shear strength from Triaxial Test
# - Undrained shear strength from Vane Test
# - Limit pressure from pressuremeter

# %%
dfg=dfg[['σ^v_[kPa]', '(N1)60', 'PI', 'LL', 'wn','CU-Vane','Pl_[Mpa]','Cu-Tx']]

# %% [markdown]
# ## Fill missing values of NSTP by regression procedures
#
# We know that the SPT are directly linked with undrained resistance and that this one is also directly linked with Atterberg Limits and water content. We will therefore fill missing (N1)60 values by regression.
# First we need to check if there are lines that are filled with the wanted parameters:
#
# - The regressand : (N1)60
# - The regressors: 'σ^v_[kPa]', 'PI', 'LL', 'wn'
#
# We find that in 36 lines we have full data to perform such regression.

# %%
dfg.dropna(subset=['σ^v_[kPa]', '(N1)60', 'PI', 'LL', 'wn']).shape
# Out:
# (84, 28)

# %%
from sklearn.linear_model           import LinearRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
# create subdatabase without Nan

dfg_train=dfg.dropna(subset=['σ^v_[kPa]', '(N1)60', 'PI', 'LL', 'wn'])

X_train = np.array(dfg_train[['σ^v_[kPa]', 'PI', 'LL', 'wn']])
y_train = np.array(dfg_train['(N1)60'])

# %%
model = LinearRegression().fit(X_train, y_train)

# Step 4: Get results
r_sq = model.score(X_train, y_train)
intercept, coefficients = model.intercept_, model.coef_

sptc0 = intercept
sptc1 = coefficients[0]
sptc2 = coefficients[1]
sptc3 = coefficients[2]
sptc4 = coefficients[3]

print('The intercept is:', intercept)
print('The coefficients are:', coefficients)
# Out:
# The intercept is: 24.325128124343376
# The coefficients are: [-0.00324476  0.15158914 -0.12815208 -0.09884295]

# %%
dfg['(N1)60']= dfg.apply(
    lambda row: 
            sptc1 * row['σ^v_[kPa]'] + sptc2 * row.PI + sptc3 * row.LL + sptc4 * row.wn + sptc0 
            if np.isnan(row['(N1)60']) else row['(N1)60'], axis=1)

# %% [markdown]
# ## Fill missing values of Vane Undrained shear resistance (cu) by regression procedures
#
# We know that the Cu is directly linked with Atterberg Limits and water content. We also know that for clayey soil is linked with SPT. We will therefore fill missing Cu-Vane values by regression. First we need to check if there are lines that are filled with the wanted parameters:
#
# The regressand : Cu-TX
# The regressors: 'σ^v_[kPa]', 'PI', 'LL', 'wn'
# We find that in 36 lines we have full data to perform such regression.

# %%
dfg.dropna(subset=['σ^v_[kPa]', '(N1)60', 'PI', 'LL', 'wn','CU-Vane']).shape
# Out:
# (46, 28)

# %%
# create subdatabase without Nan

dfg_train=dfg.dropna(subset=['σ^v_[kPa]', '(N1)60', 'PI', 'LL', 'wn','CU-Vane'])

X_train = np.array(dfg_train[['σ^v_[kPa]', 'PI', 'LL', 'wn','(N1)60']])
y_train = np.array(dfg_train['CU-Vane'])

# %%
model = LinearRegression().fit(X_train, y_train)

# Step 4: Get results
r_sq = model.score(X_train, y_train)
intercept, coefficients = model.intercept_, model.coef_

vanec0 = intercept
vanec1 = coefficients[0]
vanec2 = coefficients[1]
vanec3 = coefficients[2]
vanec4 = coefficients[3]
vanec5 = coefficients[4]

print('The intercept is:', intercept)
print('The coefficients are:', coefficients)
# Out:
# The intercept is: 126.70319610483855
# The coefficients are: [ 0.33029828 -8.62240232  5.96322843 -1.2023325   1.69583016]

# %%
dfg['CU-Vane']= dfg.apply(
    lambda row: 
            vanec1 * row['σ^v_[kPa]'] + vanec2 * row.PI + vanec3 * row.LL + vanec4 * row.wn + vanec5 * row['(N1)60'] + vanec0 
            if np.isnan(row['CU-Vane']) else row['CU-Vane'], axis=1)

# %% [markdown]
# ## Fill missing values Limit Pressure by regression procedures
#
# Limit Presure is directly linked with Undrained Shear Resistance wich is linked with Atterberg Limits and water content. We also know that for clayey soil is linked with SPT. We will therefore fill missing Cu-Vane values by regression. First we need to check if there are lines that are filled with the wanted parameters:
#
# The regressand : Pl_[Mpa]
# The regressors: 'σ^v_[kPa]', 'PI', 'LL', 'wn', Cu-TX, CU-Vane
# We find that in 36 lines we have full data to perform such regression.

# %%
dfg.dropna(subset=['σ^v_[kPa]', '(N1)60', 'PI', 'LL', 'wn','CU-Vane','Pl_[Mpa]']).shape
# Out:
# (27, 28)

# %%
# create subdatabase without Nan

dfg_train=dfg.dropna(subset=['σ^v_[kPa]', '(N1)60', 'PI', 'LL', 'wn','CU-Vane','Pl_[Mpa]'])

X_train = np.array(dfg_train[['σ^v_[kPa]', 'PI', 'LL', 'wn','(N1)60','CU-Vane']])
y_train = np.array(dfg_train['Pl_[Mpa]'])

# %%
model = LinearRegression().fit(X_train, y_train)

# Step 4: Get results
r_sq = model.score(X_train, y_train)
intercept, coefficients = model.intercept_, model.coef_

plc0 = intercept
plc1 = coefficients[0]
plc2 = coefficients[1]
plc3 = coefficients[2]
plc4 = coefficients[3]
plc5 = coefficients[4]
plc6 = coefficients[5]

print('The intercept is:', intercept)
print('The coefficients are:', coefficients)
# Out:
# The intercept is: 1.1163211705610268
# The coefficients are: [-0.00092829  0.09360751 -0.07601579  0.01832922  0.04537081 -0.00029465]

# %%
dfg["Pl_[Mpa]"]= dfg.apply(
    lambda row: 
            plc1 * row['σ^v_[kPa]'] + plc2 * row.PI + plc3 * row.LL + plc4 * row.wn + plc5 * row['(N1)60'] + plc6 * row['CU-Vane'] + plc0  
            if np.isnan(row["Pl_[Mpa]"]) else row["Pl_[Mpa]"], axis=1)
# Out:
# C:\Users\Fabrizio\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ## Fill missing values Triaxial Cu by regression procedures
#
# Triaxial Test Cu is directly linked with Vane test Undrained Shear Resistance and Limit pressures wich are linked with Atterberg Limits and water content. We also know that for clayey soil is linked with SPT. We will therefore fill missing Cu-Vane values by regression. First we need to check if there are lines that are filled with the wanted parameters:
#
# The regressand : Cu-Tx
# The regressors: 'σ^v_[kPa]', 'PI', 'LL', 'wn', Cu-TX, CU-Vane, Pl_[Mpa]
# We find that in 36 lines we have full data to perform such regression.

# %%
dfg.dropna(subset=['σ^v_[kPa]', '(N1)60', 'PI', 'LL', 'wn','CU-Vane','Pl_[Mpa]','Cu-Tx']).shape
# Out:
# (26, 8)

# %%
# create subdatabase without Nan

dfg_train=dfg.dropna(subset=['σ^v_[kPa]', '(N1)60', 'PI', 'LL', 'wn','CU-Vane','Pl_[Mpa]','Cu-Tx'])

X_train = np.array(dfg_train[['σ^v_[kPa]', 'PI', 'LL', 'wn','(N1)60','CU-Vane','Pl_[Mpa]']])
y_train = np.array(dfg_train['Cu-Tx'])

# %%
model = LinearRegression().fit(X_train, y_train)

# Step 4: Get results
r_sq = model.score(X_train, y_train)
intercept, coefficients = model.intercept_, model.coef_

plc0 = intercept
plc1 = coefficients[0]
plc2 = coefficients[1]
plc3 = coefficients[2]
plc4 = coefficients[3]
plc5 = coefficients[4]
plc6 = coefficients[5]
plc7 = coefficients[6]

print('The intercept is:', intercept)
print('The coefficients are:', coefficients)
# Out:
# The intercept is: 163.92418038146462
# The coefficients are: [ 0.63707711  4.60660853 -3.80838256  0.25288526 -0.03397655 -0.19494553
#   0.72327004]

# %%
dfg["Cu-Tx"]= dfg.apply(
    lambda row: 
            plc1 * row['σ^v_[kPa]'] + plc2 * row.PI + plc3 * row.LL + plc4 * row.wn + plc5 * row['(N1)60'] + plc6 * row['CU-Vane']+ plc6 * row['Pl_[Mpa]'] + plc0  
            if np.isnan(row["Cu-Tx"]) else row["Cu-Tx"], axis=1)
# Out:
# C:\Users\Fabrizio\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
dfg
# Out:
#              σ^v_[kPa]     (N1)60         PI         LL    wn     CU-Vane  Pl_[Mpa]       Cu-Tx
# Zarr0,25_m
# 0.75         13.500000  19.363083  34.000000  57.000000  28.0  177.075755  1.293106   83.722290
# 1.50         27.000000   8.500000  42.666667  68.666667  30.0  155.551684  0.755122   92.991401
# 1.75         31.500000  18.744321  51.333333  80.333333  30.0   90.000000  1.159467  103.703175
# 2.00         34.333333  27.329827  60.000000  92.000000  30.0  241.000000  1.426290   71.220541
# 2.50         44.742857  28.791405  46.000000  77.000000  27.4  241.000000  1.265016   69.809708
# ...                ...        ...        ...        ...   ...         ...       ...         ...
# 59.50       555.750000  14.818291  47.000000  81.000000  45.0  359.059398  0.250000  366.841997
# 60.00       555.000000  14.820724  47.000000  81.000000  45.0  358.815801  0.230000  366.415494
# 61.50       572.250000  20.701967  47.000000  81.000000  45.0  374.487035  0.481116  374.101259
# 63.00       583.500000  26.651854  47.000000  81.000000  45.0  388.292889  0.736556  378.325033
# 66.50       609.750000  20.055274  47.000000  81.000000  45.0  385.776539  0.413638  395.825939
#
# [153 rows x 8 columns]

# %%
plt.figure(figsize=(6,10))
plt.plot( dfg['Cu-Tx'],dfg.index, 'b-', label='CU TX')
plt.plot( dfo['Cu-Tx'],dfo['Zarr0,25_m'], 'b.', label='CU TX Real',markersize=10)
plt.plot( dfg['CU-Vane'],dfg.index, 'r-', label='CU Vane')
plt.plot( dfo['CU-Vane'],dfo['Zarr0,25_m'], 'r.', label='CU Vane Real',markersize=10)
plt.plot( dfg['(N1)60']*10,dfg.index, 'm-', label='CU SPT Stroud')
plt.plot( dfo['(N1)60']*10,dfo['Zarr0,25_m'], 'm.', label='CU SPT Stroud__Real',markersize=10)
plt.ylim(60,0); plt.ylabel('depth [m]'); plt.legend(); plt.title('paramters vs depth')
# Out:
# Text(0.5, 1.0, 'paramters vs depth')

# %% [markdown]
# ## Save the database as h5 py format
#
# it requires pip intall tables
# e import h5py

# %%
import h5py

# %%
dfg.to_hdf('dfg.h5', key='losses')
dfo.to_hdf('dfo.h5', key='losses')

# %%
dfg_imported = pd.read_hdf('dfg.h5', key='losses')
dfo_imported = pd.read_hdf('dfo.h5', key='losses')

# %% [markdown]
# ## Define correlation between variables

# %% [markdown]
# Before running a regression the first thing do do is :
#
# - Check the principal rules of validi of LR
#    - Homoskedaticity
#    - Errors non correlated with regressor
#    - ...
#    - ...
# - Successively we have to discern the variables that are correlated with the regressand. In fact selecting too many variables may lead to overfitting or may lead to wrong estimation.

# %%
dfg.corr()['Cu-Tx'].sort_values()
# Out:
# Pl_[Mpa]    -0.426261
# (N1)60      -0.144367
# PI           0.097435
# LL           0.151239
# wn           0.249759
# CU-Vane      0.408533
# σ^v_[kPa]    0.955419
# Cu-Tx        1.000000
# Name: Cu-Tx, dtype: float64

# %%
# Calculate correlation coefficient
def corrfunc(x, y, **kws):
    r, _ = stats.pearsonr(x, y)
    ax = plt.gca()
    ax.annotate("r = {:.2f}".format(r),
                xy=(.1, .6), xycoords=ax.transAxes,
               size = 24)
    
cmap = sns.cubehelix_palette(light=1, dark = 0.1,
                             hue = 0.5, as_cmap=True)

sns.set_context(font_scale=2)

# Pair grid set up
g = sns.PairGrid(dfg)

# Scatter plot on the upper triangle
g.map_upper(plt.scatter, s=10, color = 'b')

# Distribution on the diagonal
g.map_diag(sns.distplot, kde=False, color = 'red')

# Density Plot and Correlation coefficients on the lower triangle
g.map_lower(sns.kdeplot, cmap = cmap)
g.map_lower(corrfunc);

# %% [markdown]
# ## Let's train the model
#
# We will now use the package sklearn that envelop several machine learning algorithms. We will train some of them and we will check wich one is the most performing.
#
# First of all we are going to split the data randomly between train and test data, by mean of a method enmbedded in the sklearn package. The parameters are set such that 5% of the data will be kept aside from training and will be used to check the godness of the model.

# %%
X_train, X_test, y_train, y_test = train_test_split(dfg.loc[:,dfg.columns!='Cu-Tx'], 
                                                    dfg['Cu-Tx'], 
                                                    test_size = 0.05,
                                                    random_state=42)

# %% [markdown]
# For this regression task, we will use two standard metrics:
#
# - Mean Absolute Error (MAE)
#
# $$\begin{equation}
# \frac{1}{n} \sum_{i=1}^{n} \lvert x_{i} - \bar{x_{i}}\lvert
# \end{equation}$$
#
# - Root Mean Squared Error (RMSE)
#
# $$\begin{equation}
# \sqrt{\frac{1}{n} \sum_{i=1}^{n} (x_{i} - \bar{x_{i}})^2}
# \end{equation}$$

# %%
# Calculate mae and rmse
def evaluate_predictions(predictions, real):
    mae = np.mean(abs(predictions - real))
    rmse = np.sqrt(np.mean((predictions - real) ** 2))
    
    return mae, rmse

# %%
# Naive baseline is the median
median_pred = y_train.median()
median_preds = [median_pred for _ in range(len(X_test))]
real = y_test

# %%
# Display the naive baseline metrics
mb_mae, mb_rmse = evaluate_predictions(median_preds, real)
print('Median Baseline  MAE: {:.4f}'.format(mb_mae))
print('Median Baseline RMSE: {:.4f}'.format(mb_rmse))
# Out:
# Median Baseline  MAE: 35.9048
# Median Baseline RMSE: 49.7833

# %%
# Evaluate several ml models by training on training set and testing on testing set
def evaluate(X_train, X_test, y_train, y_test):
    # Names of models
    model_name_list = ['Linear Regression', 'ElasticNet Regression',
                      'Random Forest', 'Extra Trees', 'SVM',
                       'Gradient Boosted', 'Baseline']
    
    # Instantiate the models
    model1 = LinearRegression()
    model2 = ElasticNet(alpha=1.0, l1_ratio=0.5)
    model3 = RandomForestRegressor(n_estimators=50)
    model4 = ExtraTreesRegressor(n_estimators=50)
    model5 = SVR(kernel='rbf', degree=3, C=1.0, gamma='auto')
    model6 = GradientBoostingRegressor(n_estimators=20)
    
    
    # Dataframe for results
    results = pd.DataFrame(columns=['mae', 'rmse'], index = model_name_list)
    
    # Train and predict with each model
    for i, model in enumerate([model1, model2, model3, model4, model5, model6]):
        model.fit(X_train, y_train)
        predictions = model.predict(X_test)
        
        # Metrics
        mae = np.mean(abs(predictions - y_test))
        rmse = np.sqrt(np.mean((predictions - y_test) ** 2))
        
        # Insert results into the dataframe
        model_name = model_name_list[i]
        results.loc[model_name, :] = [mae, rmse]
    
    # Median Value Baseline Metrics
    baseline = np.median(y_train)
    baseline_mae = np.mean(abs(baseline - y_test))
    baseline_rmse = np.sqrt(np.mean((baseline - y_test) ** 2))
    
    results.loc['Baseline', :] = [baseline_mae, baseline_rmse]
    
    return results

# %%
results = evaluate(X_train, X_test, y_train, y_test)

# %%
plt.figure(figsize=(12, 8))
matplotlib.rcParams['font.size'] = 16
# Root mean squared error
ax =  plt.subplot(1, 2, 1)
results.sort_values('mae', ascending = True).plot.bar(y = 'mae', color = 'b', ax = ax)
plt.title('Model Mean Absolute Error'); plt.ylabel('MAE');

# Median absolute percentage error
ax = plt.subplot(1, 2, 2)
results.sort_values('rmse', ascending = True).plot.bar(y = 'rmse', color = 'r', ax = ax)
plt.title('Model Root Mean Squared Error'); plt.ylabel('RMSE');

plt.tight_layout()

# %%
results
# Out:
#                            mae     rmse
# Linear Regression      4.87517  10.8597
# ElasticNet Regression    5.059  10.0669
# Random Forest          12.8066  15.7582
# Extra Trees            14.0531  17.5657
# SVM                    35.9048  49.7811
# Gradient Boosted       13.8196  18.3593
# Baseline               35.9048  49.7833

# %% [markdown]
# ## Formula from Ordinary Least Squares Linear Regression

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

ols_formula = 'Cu-Tx=%0.2f+' % lr.intercept_
for i, col in enumerate(X_train.columns[:]):
    ols_formula += '%0.2f * %s+' % (lr.coef_[i], col)
    
' '.join(ols_formula.split(' ')[:-1])
# Out:
# 'Cu-Tx=164.89+0.64 * σ^v_[kPa]+-0.02 * (N1)60+4.72 * PI+-3.91 * LL+0.29 * wn+-0.19 * CU-Vane+-0.12 *'

# %% [markdown]
# ## Implementing Bayesian Linear Regression

# %%
# Formula for Bayesian Linear Regression (follows R formula syntax
formula = 'Cu-Tx ~ ' + ' + '.join(['%s' % variable for variable in X_train.columns[1:]])
formula
# Out:
# 'Cu-Tx ~ (N1)60 + PI + LL + wn + CU-Vane + Pl_[Mpa]'

# %% [markdown]
# Create Model in PyMC3 and Sample from Posterior.
# We now build the model using the formula defined above and a normal distribution for the data likelihood. Then, we let a Markov Chain Monte Carlo algorithm draw samples from the posterior to approximate the posterior for each of the model parameters

# %%
# Context for the model
with pm.Model() as normal_model:
    
    # The prior for the model parameters will be a normal distribution
    family = pm.glm.families.Normal()
    
    # Creating the model requires a formula and data (and optionally a family)
    pm.GLM.from_formula(formula, data = X_train, family = family)
    
    # Perform Markov Chain Monte Carlo sampling
    normal_trace = pm.sample(draws=2000, chains = 2, tune = 500, njobs=-1)

# %%
X_train
